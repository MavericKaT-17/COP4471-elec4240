# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'assignment1'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/MyDrive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\Drive/$FOLDERNAME

# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.321303
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ since the weights are randomly generated, the expected probability for each class (10 in total) is 0.1.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.237915 analytic: 0.237915, relative error: 4.204183e-07
# numerical: 1.252090 analytic: 1.252090, relative error: 6.024172e-08
# numerical: 0.597472 analytic: 0.597471, relative error: 1.563760e-07
# numerical: -1.529549 analytic: -1.529549, relative error: 2.674959e-09
# numerical: -1.353251 analytic: -1.353251, relative error: 3.979131e-08
# numerical: -1.380012 analytic: -1.380012, relative error: 6.234717e-08
# numerical: 0.562607 analytic: 0.562607, relative error: 6.309604e-08
# numerical: -1.602479 analytic: -1.602479, relative error: 2.497868e-08
# numerical: 0.923031 analytic: 0.923031, relative error: 1.083201e-08
# numerical: -0.148863 analytic: -0.148863, relative error: 4.110477e-07
# numerical: 1.421589 analytic: 1.418701, relative error: 1.016655e-03
# numerical: -0.002944 analytic: -0.005459, relative error: 2.992830e-01
# numerical: -0.218538 analytic: -0.205459, relative error: 3.084701e-02
# numerical: -4.675956 analytic: -4.679502, relative error: 3.789950e-04
# numerical: -0.284696 analytic: -0.289721, relative error: 8.748161e-03
# numerical: 0.222193 analytic: 0.230109, relative error: 1.750168e-02
# numerical: -0.029826 analytic: -0.029193, relative error: 1.073068e-02
# numerical: 0.303086 analytic: 0.293376, relative error: 1.628071e-02
# numerical: -0.762636 analytic: -0.760496, relative error: 1.405221e-03
# numerical: -3.701361 analytic: -3.699651, relative error: 2.310355e-04

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.321303e+00 computed in 0.206138s
# vectorized loss: 2.321303e+00 computed in 0.004433s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [1e-7, 5e-8, 5e-7, 1e-6, 2e-6, 5e-6, 1e-5, 5e-5, 1e-4, 5e-4, 1e-3, 5e-3, 1e-2, 5e-2]
regularization_strengths = [2.5e4, 5e4, 1e4, 1e5, 2.5e5, 5e5, 1e6, 2.5e6, 5e6, 1e7, 2.5e7, 5e7, 1e8]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train, y_train, learning_rate=lr, reg=reg, num_iters=100, verbose=False)
        y_train_pred = softmax.predict(X_train)
        y_val_pred = softmax.predict(X_val)
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)
        results[(lr, reg)] = (train_accuracy, val_accuracy)
        if val_accuracy > best_val:
            best_val = val_accuracy
            best_softmax = softmax

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# c:\Users\erick\Documents\VS_code\ELEC4240\assignment1\cs231n\classifiers\softmax.py:92: RuntimeWarning: divide by zero encountered in log
#   loss = -np.sum(np.log(correct_probs))
# c:\Users\erick\Documents\VS_code\ELEC4240\assignment1\cs231n\classifiers\softmax.py:93: RuntimeWarning: overflow encountered in scalar multiply
#   loss /= X.shape[0] + reg * np.sum(W * W)
# c:\Users\erick\Documents\VS_code\ELEC4240\assignment1\cs231n\classifiers\softmax.py:93: RuntimeWarning: invalid value encountered in scalar divide
#   loss /= X.shape[0] + reg * np.sum(W * W)
# c:\Users\erick\Documents\VS_code\ELEC4240\assignment1\cs231n\classifiers\softmax.py:93: RuntimeWarning: overflow encountered in multiply
#   loss /= X.shape[0] + reg * np.sum(W * W)
# c:\Users\erick\Documents\VS_code\ELEC4240\assignment1\cs231n\classifiers\softmax.py:100: RuntimeWarning: overflow encountered in multiply
#
# c:\Users\erick\Documents\VS_code\ELEC4240\assignment1\cs231n\classifiers\softmax.py:86: RuntimeWarning: overflow encountered in subtract
#   scores -= np.max(scores, axis=1, keepdims=True)
# c:\Users\erick\Documents\VS_code\ELEC4240\assignment1\cs231n\classifiers\softmax.py:86: RuntimeWarning: invalid value encountered in subtract
#   scores -= np.max(scores, axis=1, keepdims=True)
# lr 5.000000e-08 reg 1.000000e+04 train accuracy: 0.160694 val accuracy: 0.165000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.131265 val accuracy: 0.139000
# lr 5.000000e-08 reg 5.000000e+04 train accuracy: 0.125000 val accuracy: 0.131000
# lr 5.000000e-08 reg 1.000000e+05 train accuracy: 0.126755 val accuracy: 0.124000
# lr 5.000000e-08 reg 2.500000e+05 train accuracy: 0.199510 val accuracy: 0.182000
# lr 5.000000e-08 reg 5.000000e+05 train accuracy: 0.265143 val accuracy: 0.280000
# lr 5.000000e-08 reg 1.000000e+06 train accuracy: 0.236551 val accuracy: 0.248000
# lr 5.000000e-08 reg 2.500000e+06 train accuracy: 0.259653 val accuracy: 0.274000
# lr 5.000000e-08 reg 5.000000e+06 train accuracy: 0.211653 val accuracy: 0.222000
# lr 5.000000e-08 reg 1.000000e+07 train accuracy: 0.219286 val accuracy: 0.223000
# lr 5.000000e-08 reg 2.500000e+07 train accuracy: 0.110939 val accuracy: 0.110000
# lr 5.000000e-08 reg 5.000000e+07 train accuracy: 0.075061 val accuracy: 0.080000
# lr 5.000000e-08 reg 1.000000e+08 train accuracy: 0.111551 val accuracy: 0.128000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.153061 val accuracy: 0.144000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.169633 val accuracy: 0.179000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.180367 val accuracy: 0.190000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.210939 val accuracy: 0.216000
# lr 1.000000e-07 reg 2.500000e+05 train accuracy: 0.260714 val accuracy: 0.276000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.256735 val accuracy: 0.270000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.229714 val accuracy: 0.238000
# lr 1.000000e-07 reg 2.500000e+06 train accuracy: 0.238082 val accuracy: 0.244000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.183306 val accuracy: 0.202000
# lr 1.000000e-07 reg 1.000000e+07 train accuracy: 0.090776 val accuracy: 0.099000
# lr 1.000000e-07 reg 2.500000e+07 train accuracy: 0.085653 val accuracy: 0.080000
# lr 1.000000e-07 reg 5.000000e+07 train accuracy: 0.095082 val accuracy: 0.096000
# lr 1.000000e-07 reg 1.000000e+08 train accuracy: 0.105286 val accuracy: 0.103000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.249245 val accuracy: 0.243000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.308388 val accuracy: 0.315000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.304000 val accuracy: 0.308000
# lr 5.000000e-07 reg 1.000000e+05 train accuracy: 0.280592 val accuracy: 0.281000
# lr 5.000000e-07 reg 2.500000e+05 train accuracy: 0.242816 val accuracy: 0.262000
# lr 5.000000e-07 reg 5.000000e+05 train accuracy: 0.246429 val accuracy: 0.262000
# lr 5.000000e-07 reg 1.000000e+06 train accuracy: 0.205510 val accuracy: 0.193000
# lr 5.000000e-07 reg 2.500000e+06 train accuracy: 0.096612 val accuracy: 0.100000
# lr 5.000000e-07 reg 5.000000e+06 train accuracy: 0.104327 val accuracy: 0.116000
# lr 5.000000e-07 reg 1.000000e+07 train accuracy: 0.121429 val accuracy: 0.122000
# lr 5.000000e-07 reg 2.500000e+07 train accuracy: 0.093306 val accuracy: 0.093000
# lr 5.000000e-07 reg 5.000000e+07 train accuracy: 0.100796 val accuracy: 0.111000
# lr 5.000000e-07 reg 1.000000e+08 train accuracy: 0.095204 val accuracy: 0.091000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.315449 val accuracy: 0.344000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.308286 val accuracy: 0.313000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.284776 val accuracy: 0.297000
# lr 1.000000e-06 reg 1.000000e+05 train accuracy: 0.269776 val accuracy: 0.277000
# lr 1.000000e-06 reg 2.500000e+05 train accuracy: 0.240939 val accuracy: 0.230000
# lr 1.000000e-06 reg 5.000000e+05 train accuracy: 0.213408 val accuracy: 0.198000
# lr 1.000000e-06 reg 1.000000e+06 train accuracy: 0.078429 val accuracy: 0.091000
# lr 1.000000e-06 reg 2.500000e+06 train accuracy: 0.106837 val accuracy: 0.111000
# lr 1.000000e-06 reg 5.000000e+06 train accuracy: 0.119265 val accuracy: 0.129000
# lr 1.000000e-06 reg 1.000000e+07 train accuracy: 0.090163 val accuracy: 0.099000
# lr 1.000000e-06 reg 2.500000e+07 train accuracy: 0.119122 val accuracy: 0.105000
# lr 1.000000e-06 reg 5.000000e+07 train accuracy: 0.110776 val accuracy: 0.098000
# lr 1.000000e-06 reg 1.000000e+08 train accuracy: 0.095592 val accuracy: 0.104000
# lr 2.000000e-06 reg 1.000000e+04 train accuracy: 0.330367 val accuracy: 0.342000
# lr 2.000000e-06 reg 2.500000e+04 train accuracy: 0.307633 val accuracy: 0.319000
# lr 2.000000e-06 reg 5.000000e+04 train accuracy: 0.270102 val accuracy: 0.285000
# lr 2.000000e-06 reg 1.000000e+05 train accuracy: 0.246265 val accuracy: 0.251000
# lr 2.000000e-06 reg 2.500000e+05 train accuracy: 0.207143 val accuracy: 0.210000
# lr 2.000000e-06 reg 5.000000e+05 train accuracy: 0.098408 val accuracy: 0.089000
# lr 2.000000e-06 reg 1.000000e+06 train accuracy: 0.116878 val accuracy: 0.126000
# lr 2.000000e-06 reg 2.500000e+06 train accuracy: 0.099878 val accuracy: 0.125000
# lr 2.000000e-06 reg 5.000000e+06 train accuracy: 0.141837 val accuracy: 0.137000
# lr 2.000000e-06 reg 1.000000e+07 train accuracy: 0.112796 val accuracy: 0.114000
# lr 2.000000e-06 reg 2.500000e+07 train accuracy: 0.095673 val accuracy: 0.089000
# lr 2.000000e-06 reg 5.000000e+07 train accuracy: 0.116796 val accuracy: 0.125000
# lr 2.000000e-06 reg 1.000000e+08 train accuracy: 0.112796 val accuracy: 0.094000
# lr 5.000000e-06 reg 1.000000e+04 train accuracy: 0.297286 val accuracy: 0.308000
# lr 5.000000e-06 reg 2.500000e+04 train accuracy: 0.151939 val accuracy: 0.153000
# lr 5.000000e-06 reg 5.000000e+04 train accuracy: 0.202367 val accuracy: 0.201000
# lr 5.000000e-06 reg 1.000000e+05 train accuracy: 0.103041 val accuracy: 0.102000
# lr 5.000000e-06 reg 2.500000e+05 train accuracy: 0.086816 val accuracy: 0.076000
# lr 5.000000e-06 reg 5.000000e+05 train accuracy: 0.073429 val accuracy: 0.080000
# lr 5.000000e-06 reg 1.000000e+06 train accuracy: 0.097020 val accuracy: 0.083000
# lr 5.000000e-06 reg 2.500000e+06 train accuracy: 0.084571 val accuracy: 0.086000
# lr 5.000000e-06 reg 5.000000e+06 train accuracy: 0.138612 val accuracy: 0.137000
# lr 5.000000e-06 reg 1.000000e+07 train accuracy: 0.087816 val accuracy: 0.095000
# lr 5.000000e-06 reg 2.500000e+07 train accuracy: 0.077898 val accuracy: 0.079000
# lr 5.000000e-06 reg 5.000000e+07 train accuracy: 0.089204 val accuracy: 0.096000
# lr 5.000000e-06 reg 1.000000e+08 train accuracy: 0.099714 val accuracy: 0.101000
# lr 1.000000e-05 reg 1.000000e+04 train accuracy: 0.199082 val accuracy: 0.191000
# lr 1.000000e-05 reg 2.500000e+04 train accuracy: 0.162816 val accuracy: 0.140000
# lr 1.000000e-05 reg 5.000000e+04 train accuracy: 0.094837 val accuracy: 0.105000
# lr 1.000000e-05 reg 1.000000e+05 train accuracy: 0.070204 val accuracy: 0.053000
# lr 1.000000e-05 reg 2.500000e+05 train accuracy: 0.085286 val accuracy: 0.082000
# lr 1.000000e-05 reg 5.000000e+05 train accuracy: 0.077898 val accuracy: 0.070000
# lr 1.000000e-05 reg 1.000000e+06 train accuracy: 0.089980 val accuracy: 0.092000
# lr 1.000000e-05 reg 2.500000e+06 train accuracy: 0.118959 val accuracy: 0.115000
# lr 1.000000e-05 reg 5.000000e+06 train accuracy: 0.080510 val accuracy: 0.085000
# lr 1.000000e-05 reg 1.000000e+07 train accuracy: 0.095531 val accuracy: 0.108000
# lr 1.000000e-05 reg 2.500000e+07 train accuracy: 0.082408 val accuracy: 0.090000
# lr 1.000000e-05 reg 5.000000e+07 train accuracy: 0.074776 val accuracy: 0.055000
# lr 1.000000e-05 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 1.000000e+04 train accuracy: 0.073714 val accuracy: 0.074000
# lr 5.000000e-05 reg 2.500000e+04 train accuracy: 0.048714 val accuracy: 0.040000
# lr 5.000000e-05 reg 5.000000e+04 train accuracy: 0.070551 val accuracy: 0.060000
# lr 5.000000e-05 reg 1.000000e+05 train accuracy: 0.079959 val accuracy: 0.078000
# lr 5.000000e-05 reg 2.500000e+05 train accuracy: 0.099163 val accuracy: 0.109000
# lr 5.000000e-05 reg 5.000000e+05 train accuracy: 0.128735 val accuracy: 0.158000
# lr 5.000000e-05 reg 1.000000e+06 train accuracy: 0.075184 val accuracy: 0.074000
# lr 5.000000e-05 reg 2.500000e+06 train accuracy: 0.116224 val accuracy: 0.133000
# lr 5.000000e-05 reg 5.000000e+06 train accuracy: 0.089612 val accuracy: 0.095000
# lr 5.000000e-05 reg 1.000000e+07 train accuracy: 0.091571 val accuracy: 0.090000
# lr 5.000000e-05 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 5.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 1.000000e+04 train accuracy: 0.092041 val accuracy: 0.085000
# lr 1.000000e-04 reg 2.500000e+04 train accuracy: 0.081980 val accuracy: 0.076000
# lr 1.000000e-04 reg 5.000000e+04 train accuracy: 0.077510 val accuracy: 0.072000
# lr 1.000000e-04 reg 1.000000e+05 train accuracy: 0.114612 val accuracy: 0.103000
# lr 1.000000e-04 reg 2.500000e+05 train accuracy: 0.102490 val accuracy: 0.116000
# lr 1.000000e-04 reg 5.000000e+05 train accuracy: 0.105653 val accuracy: 0.107000
# lr 1.000000e-04 reg 1.000000e+06 train accuracy: 0.089714 val accuracy: 0.095000
# lr 1.000000e-04 reg 2.500000e+06 train accuracy: 0.106612 val accuracy: 0.094000
# lr 1.000000e-04 reg 5.000000e+06 train accuracy: 0.110878 val accuracy: 0.105000
# lr 1.000000e-04 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 5.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-04 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-04 reg 1.000000e+04 train accuracy: 0.100163 val accuracy: 0.084000
# lr 5.000000e-04 reg 2.500000e+04 train accuracy: 0.053857 val accuracy: 0.050000
# lr 5.000000e-04 reg 5.000000e+04 train accuracy: 0.104286 val accuracy: 0.111000
# lr 5.000000e-04 reg 1.000000e+05 train accuracy: 0.088918 val accuracy: 0.079000
# lr 5.000000e-04 reg 2.500000e+05 train accuracy: 0.099245 val accuracy: 0.096000
# lr 5.000000e-04 reg 5.000000e+05 train accuracy: 0.094306 val accuracy: 0.092000
# lr 5.000000e-04 reg 1.000000e+06 train accuracy: 0.108490 val accuracy: 0.094000
# lr 5.000000e-04 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-04 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-04 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-04 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-04 reg 5.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-04 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 reg 1.000000e+04 train accuracy: 0.072735 val accuracy: 0.072000
# lr 1.000000e-03 reg 2.500000e+04 train accuracy: 0.075469 val accuracy: 0.071000
# lr 1.000000e-03 reg 5.000000e+04 train accuracy: 0.064327 val accuracy: 0.075000
# lr 1.000000e-03 reg 1.000000e+05 train accuracy: 0.066939 val accuracy: 0.065000
# lr 1.000000e-03 reg 2.500000e+05 train accuracy: 0.095122 val accuracy: 0.099000
# lr 1.000000e-03 reg 5.000000e+05 train accuracy: 0.098816 val accuracy: 0.089000
# lr 1.000000e-03 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 reg 5.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-03 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 1.000000e+04 train accuracy: 0.083571 val accuracy: 0.075000
# lr 5.000000e-03 reg 2.500000e+04 train accuracy: 0.069878 val accuracy: 0.063000
# lr 5.000000e-03 reg 5.000000e+04 train accuracy: 0.063020 val accuracy: 0.057000
# lr 5.000000e-03 reg 1.000000e+05 train accuracy: 0.103408 val accuracy: 0.099000
# lr 5.000000e-03 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 5.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 5.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-03 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+04 train accuracy: 0.053469 val accuracy: 0.050000
# lr 1.000000e-02 reg 2.500000e+04 train accuracy: 0.059224 val accuracy: 0.070000
# lr 1.000000e-02 reg 5.000000e+04 train accuracy: 0.094878 val accuracy: 0.097000
# lr 1.000000e-02 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 5.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 5.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 1.000000e-02 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 1.000000e+04 train accuracy: 0.066531 val accuracy: 0.060000
# lr 5.000000e-02 reg 2.500000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 2.500000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 5.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 2.500000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 5.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 1.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 2.500000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 5.000000e+07 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-02 reg 1.000000e+08 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.344000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.260000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$ True
#
#
# $\color{blue}{\textit Your Explanation:}$ there will also be loss in softmax since it calculates the probabilities, on the other hand, the loss can be 0 if the new datapoint is predicted correctly

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
